# %%
#problem 1
https://codeforces.com/contest/495/submission/192222308

# %%
#problem 2
https://codeforces.com/gym/101810/submission/192409234

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv(r'airbnb.csv')

df.head()
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30478 entries, 0 to 30477
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     30478 non-null  int64
#  1   Host Since                  30475 non-null  object
#  2   Name                        30478 non-null  object
#  3   Neighbourhood               30478 non-null  object
#  4   Property Type               30475 non-null  object
#  5   Review Scores Rating (bin)  22155 non-null  float64
#  6   Room Type                   30478 non-null  object
#  7   Zipcode                     30344 non-null  float64
#  8   Beds                        30393 non-null  float64
#  9   Number of Records           30478 non-null  int64
#  10  Number Of Reviews           30478 non-null  int64
#  11  Price                       30478 non-null  object
#  12  Review Scores Rating        22155 non-null  float64
# ...

# %%
df.describe()
# Out:
#             Host Id  Review Scores Rating (bin)       Zipcode          Beds  \
# count  3.047800e+04                22155.000000  30344.000000  30393.000000
# mean   1.273171e+07                   90.738659  10584.854831      1.530089
# std    1.190270e+07                    9.059519    921.299397      1.015359
# min    5.000000e+02                   20.000000   1003.000000      0.000000
# 25%    2.701298e+06                   85.000000  10017.000000      1.000000
# 50%    8.551693e+06                   90.000000  10065.000000      1.000000
# 75%    2.120617e+07                  100.000000  11216.000000      2.000000
# max    4.303307e+07                  100.000000  99135.000000     16.000000
#
#        Number of Records  Number Of Reviews  Review Scores Rating
# count            30478.0       30478.000000          22155.000000
# mean                 1.0          12.018735             91.993230
# std                  0.0          21.980703              8.850373
# ...

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    3
# Review Scores Rating (bin)    8309
# Room Type                        0
# Zipcode                        134
# Beds                            85
# Number of Records                0
# Number Of Reviews                0
# Price                            0
# Review Scores Rating          8309
# dtype: int64

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 12122046    32
# 26377263    30
# 417504      28
# 35927005    26
# 20780082    21
#             ..
# 4939720      1
# 4938741      1
# 4940121      1
# 4938115      1
# 42999189     1
# Name: Host Id, Length: 24421, dtype: int64
# 2/10/2014     70
# 6/16/2015     59
# 6/18/2012     50
# 1/19/2015     49
# 12/2/2013     49
#               ..
# 9/11/2009      1
# 9/1/2009       1
# 5/10/2010      1
# 8/26/2009      1
# 12/21/2009     1
# Name: Host Since, Length: 2240, dtype: int64
# Charming West Village studio          15
# HOME AWAY FROM HOME                   12
# Private room in Brooklyn              12
# Loft Suite @ The Box House Hotel      11
# Private Room in WILLIAMSBURG          11
#                                       ..
# Cozy Room with a Hammock!              1
# Private Room in Heart of WBurg         1
# Park View Apt, 15 Min to Manhattan     1
# Small Town in the Big Apple!           1
# Huge Beautiful Bedroom - Astoria       1
# ...

# %%
df.isnull().sum()
# Out:
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    3
# Review Scores Rating (bin)    8309
# Room Type                        0
# Zipcode                        134
# Beds                            85
# Number of Records                0
# Number Of Reviews                0
# Price                            0
# Review Scores Rating          8309
# dtype: int64

# %%
df[df["Review Scores Rating"].isna()]
# Out:
#         Host Id Host Since                                Name Neighbourhood   \
# 0       5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1      33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2      39608626        NaN                Sunny Room in Harlem      Manhattan
# 3           500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 13         2787   9/7/2008     Renovated and spacious townhome       Brooklyn
# ...         ...        ...                                 ...            ...
# 30473  43022976  8/31/2015   10 Mins to Time Square/two floors         Queens
# 30474  42993382  8/31/2015       1BR ocean view & F,Q train st       Brooklyn
# 30475  43033067  8/31/2015                Amazing Private Room       Brooklyn
# 30476  43000991  8/31/2015   Charming private female room: UWS      Manhattan
# 30477  42999189  8/31/2015    Huge Beautiful Bedroom - Astoria         Queens
#
# ...

# %%
df[df["Property Type"].isna()]
# Out:
#         Host Id Host Since                              Name Neighbourhood   \
# 433       58979  12/1/2009  Bright and Cheery Chelsea Studio      Manhattan
# 7893    2837739   7/5/2012     Hip & Spacious 1BD in the LES      Manhattan
# 20551  16915992  6/17/2014       Entire home/apt in New York      Manhattan
#
#       Property Type  Review Scores Rating (bin)        Room Type  Zipcode  \
# 433             NaN                        95.0     Private room  10011.0
# 7893            NaN                        85.0  Entire home/apt  10002.0
# 20551           NaN                         NaN  Entire home/apt  10002.0
#
#        Beds  Number of Records  Number Of Reviews Price  Review Scores Rating
# 433     1.0                  1                 28   165                  98.0
# 7893    1.0                  1                 24   150                  89.0
# 20551   2.0                  1                  0   120                   NaN

# %%
df['Property Type'].fillna('Apartment',inplace=True)

# %%
df.drop(index=[0,1,2],inplace=True)

# %%
df.drop(columns=["Review Scores Rating (bin)",'Zipcode'],inplace=True)

# %%
df['Beds'].fillna(1,inplace=True)

# %%
df.isna().sum()
# Out:
# Host Id                    0
# Host Since                 0
# Name                       0
# Neighbourhood              0
# Property Type              0
# Room Type                  0
# Beds                       0
# Number of Records          0
# Number Of Reviews          0
# Price                      0
# Review Scores Rating    8306
# dtype: int64

# %%
df.head()
# Out:
#    Host Id Host Since                                 Name Neighbourhood   \
# 3      500  6/26/2008   Gorgeous 1 BR with Private Balcony      Manhattan
# 4      500  6/26/2008             Trendy Times Square Loft      Manhattan
# 5     1039  7/25/2008   Big Greenpoint 1BD w/ Skyline View       Brooklyn
# 6     1783  8/12/2008                         Amazing Also      Manhattan
# 7     2078  8/15/2008  Colorful, quiet, & near the subway!       Brooklyn
#
#   Property Type        Room Type  Beds  Number of Records  Number Of Reviews  \
# 3     Apartment  Entire home/apt   3.0                  1                  0
# 4     Apartment     Private room   3.0                  1                 39
# 5     Apartment  Entire home/apt   1.0                  1                  4
# 6     Apartment  Entire home/apt   1.0                  1                  9
# 7     Apartment     Private room   1.0                  1                 80
#
#   Price  Review Scores Rating
# ...

# %%
https://public.tableau.com/views/Book2_16758057983600/Story1?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link
